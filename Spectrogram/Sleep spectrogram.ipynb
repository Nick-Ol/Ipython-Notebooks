# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pylab import *
# %matplotlib inline

# %%
def get_signal(path_to_csv_file):
    sig = pd.read_csv(path_to_csv_file, squeeze=True).tolist()
    return sig

# %%
signal = get_signal("subject13_FPz_A1.csv")
len(signal)
# Out:
# 6667999

# %%
start = 1000000

x = signal[start:(start + 7200*200)]

NFFT = 200*3
Fs = 200
test = specgram(x, Fs, NFFT)
